# %%
# %matplotlib nbagg

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
X = pd.read_csv('Logs/test.log').as_matrix()
Y = pd.read_csv('Logs/train.log').as_matrix()
# Out:
# 99.629999999999995

# %%
plt.close()
plt.figure(figsize=(12,8))
plt.plot(np.arange(0, X.shape[0]), X, label='Test Accuracy')
plt.plot(np.arange(0, Y.shape[0]), Y, label='Train Accuracy')
plt.title(r'Accuracy vs Epoch for best performing model (Noise, Dropout, Convolution & Rotation)')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='best')

#plt.savefig('bestPerformance.png')
# Out:
# <img src="data:image/png;base64,...">

# %%
thetas = [0.2, 0.3 ]
tests_vals = [99.57, 99.53 ]
train_vals = [99.90, 99.87 ]

# %%
dropout = pd.read_csv('Logs/test.log.dropout').as_matrix()
dropout = dropout[:20]
convolution = pd.read_csv('Logs/test.log.convolution').as_matrix()
print(dropout.shape)
print(convolution.shape)
# Out:
# (20, 1)
# (20, 1)

# %%
plt.close()
plt.plot(dropout, label='Convolution')
plt.plot(convolution, label='Dropout')
plt.title(r'Test accuracy vs Epoch for Convolution & Dropout models ( $ \theta =0.3 $)')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='best')

#plt.savefig('convolution_dropout.png')
# Out:
# <img src="data:image/png;base64,...">
