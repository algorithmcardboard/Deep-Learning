-- %%
require 'image'
require 'manifold'
require 'cunn'
require 'torch'

-- %%
centroids = torch.load('/home/ubuntu/kernels.t7')

-- %%
centroids = centroids:reshape(512, 3, 13, 13):float()

-- %%
--itorch.image(centroids[{{1,10}, {}, {}, {}}])
itorch.image(centroids)
-- Out:
-- Console does not support images
